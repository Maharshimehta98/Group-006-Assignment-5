# %%
#Import Python Libraries
import numpy as np
import pandas as pd

# %%
#Loading Table
df = pd.read_csv(r'C:\Users\dpk00\OneDrive\Documents\Data Analytics\1202-02 Data Analysis Tools Analytics\youtube_dataset.csv',encoding='latin-1')
df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
# A function to calculate distribustion
def distribution(n):
        df_top = df.nlargest(1000,'subscribers')
        count = n.value_counts()
        print(count)

# %%
df_ch = df[['channeltype']]
distribution(df_ch)
# Out:
# channeltype
# Entertainment    1037
# Music             760
# Games             449
# People            392
# Comedy            275
# Howto             223
# Film              176
# Education         142
# Tech               78
# Sports             56
# News               55
# Autos              14
# Travel             11
# Animals             9
# Nonprofit           3
# Shows               1
# dtype: int64

# %%
# Loading top 1000 records in separate csv
top1000 = df.head(1000)
top1000.to_csv(r'C:\Users\dpk00\OneDrive\Documents\Data Analytics\1202-02 Data Analysis Tools Analytics\export_dataframe.csv', index = False, header=True)
top1000.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
# Out:
# ...
#      ---------------------------------------- 43.8/43.8 kB 2.2 MB/s eta 0:00:00
# ...
